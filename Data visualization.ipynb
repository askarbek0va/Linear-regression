# %% [markdown]
# # Data Visualization

# %% [markdown]
# **Data visualization**
# is a field in data analysis that deals with visual representation of data. It graphically plots data and is an effective way to communicate inferences from data.
#
# Using data visualization, we can get a visual summary of our data. With pictures, maps and graphs, the human mind has an easier time processing and understanding any given data. Data visualization plays a significant role in the representation of both small and large data sets, but it is especially useful when we have large data sets, in which it is impossible to see all of our data, let alone process and understand it manually.

# %% [markdown]
# #### In the following graphs, the first graphs are the example that was given in https://www.simplilearn.com/tutorials/python-tutorial/data-visualization-in-python and the second graphs are mine(Example Data Set).

# %%
import pandas as pd
data = pd.read_csv("ExampleDataset.csv", header=0, sep=",")
for x in data.index:
  if data.loc[x, "Calories"] > 500:
    data.drop(x, inplace = True)
    
for x in data.index:
  if data.loc[x, "Duration"] < 30:
    data.drop(x, inplace = True)
print(data)
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# ..        ...    ...       ...       ...
# 164        60    105       140     290.8
# 165        60    110       145     300.0
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4
#
# [136 rows x 4 columns]

# %% [markdown]
# ## Line Charts

# %% [markdown]
# A Line chart is a graph that represents information as a series of data points connected by a straight line. In line charts, each data point or marker is plotted and connected with a line or curve.

# %% [markdown]
# ### Using Matplotlib

# %%
import matplotlib.pyplot as plt
import seaborn as sns
years = range (2000, 2012)
apples = [0.895, 0.91, 0.919, 0.926, 0.929, 0.931, 0.934, 0.936, 0.937, 0.9375, 0.9372, 0.939]
oranges = [0.962, 0.941, 0.930, 0.923, 0.918, 0.908, 0.907, 0.904, 0.901, 0.898, 0.9, 0.896]

plt.plot (years, apples)
plt.plot (years, oranges)

plt.figure(figsize=(10,6))

plt.plot (years,apples,marker='o')
plt.plot (years,oranges,marker='x')

plt.xlabel ('Year')
plt.ylabel('Yield (tons per hectare)')

plt.title("Crop Yields in Kanto")
plt.legend(['Apples','Oranges'])

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
x = data["Duration"]
y = data["Calories"]

plt.plot(x,y)
plt.plot(data['Maxpulse'], y)

plt.figure(figsize=(10,6))

plt.plot(x,y,marker='o')
plt.plot(data['Maxpulse'], y,marker='x')

plt.xlabel("Duration")
plt.ylabel ("Calories")

plt.title("ExampleDataset")
plt.legend(['Duration-Calories','Maxpulse-Calories'])

# %% [markdown]
# ### Using Seaborn

# %%
import seaborn as sns
sns.set_style("darkgrid")

plt.plot (years, apples, marker = 'x')
plt.plot (years, oranges, marker ='o')

plt.xlabel('Year')
plt.ylabel('Yield (tons per hectare)')

plt.title("Crop Yields in Kanto")
plt. legend (['Apples','Oranges '])

# %%
sns.set_style("darkgrid")

plt.figure(figsize=(10,6))

plt.plot(x,y,marker='o')
plt.plot(data['Maxpulse'], y,marker='x')

plt.xlabel("Duration")
plt.ylabel ("Calories")

plt.title("ExampleDataset")
plt.legend(['Duration-Calories','Maxpulse-Calories'])

# %% [markdown]
# ## Bar Graphs

# %% [markdown]
# When you have categorical data, you can represent it with a bar graph. A bar graph plots data with the help of bars, which represent value on the y-axis and category on the x-axis. Bar graphs use bars with varying heights to show the data which belongs to a specific category.

# %%
years = range (2000, 2006)
apples = [0.35, 0.6, 0.9, 0.8, 0.65, 0.8]
oranges = [0.4, 0.8, 0.9, 0.7, 0.6, 0.8]

plt. bar (years, oranges)

plt.xlabel ('Year')
plt.ylabel('Yield (tons per hectare)')

plt.title("Crop Yields in Kanto")
# Out:
# Text(0.5, 1.0, 'Crop Yields in Kanto')

# %%
#We can also stack bars on top of each other. Let's plot the data for apples and oranges.
plt.bar (years, apples)
plt.bar(years, oranges, bottom=apples)
# Out:
# <BarContainer object of 6 artists>

# %%
plt. bar (data["Duration"], data["Calories"], width=10)

plt.xlabel("Duration")
plt.ylabel ("Calories")

plt.title("ExampleDataset")
# Out:
# Text(0.5, 1.0, 'ExampleDataset')

# %%
plt. bar (data["Duration"], data["Maxpulse"], width=10)
plt.xlabel("Duration")
plt.ylabel ("Maxpulse")
# Out:
# Text(0, 0.5, 'Maxpulse')

# %%
plt.bar (data["Duration"], data["Maxpulse"], width=10)
plt.bar(data["Duration"], data["Calories"], bottom=data["Maxpulse"], width=10)
# Out:
# <BarContainer object of 136 artists>

# %%
sns.barplot (x='Duration', y='Calories', data=data)
#The Seaborn library also provides a barplot function that can automatically compute averages.
# Out:
# <Axes: xlabel='Duration', ylabel='Calories'>

# %% [markdown]
# ## Histograms

# %% [markdown]
# A Histogram is a bar representation of data  that varies over a range. It plots the height of the data belonging to a range along the y-axis and the range along the x-axis. Histograms are used to plot data over a range of values. They use a bar representation to show the data belonging to each range.

# %%
import numpy as np
plt.hist(data["Duration"])

#We can control the number or size of bins too with "bins=''"
# Out:
# (array([16., 35.,  0., 79.,  0.,  2.,  3.,  0.,  0.,  1.]),
#  array([ 30.,  39.,  48.,  57.,  66.,  75.,  84.,  93., 102., 111., 120.]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(data["Maxpulse"], alpha=0.4)
plt.hist(data["Pulse"], alpha=0.4)
# Out:
# (array([ 2., 15., 43., 45., 18.,  5.,  2.,  2.,  3.,  1.]),
#  array([ 80. ,  87.9,  95.8, 103.7, 111.6, 119.5, 127.4, 135.3, 143.2,
#         151.1, 159. ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# ## Scatter Plots

# %% [markdown]
# Scatter plots are used when we have to plot two or more variables present at different coordinates. The data is scattered all over the graph and is not confined to a range. Two or more variables are plotted in a Scatter Plot, with each variable being represented by a different color.

# %%
plt.figure(figsize=(10,6))
sns.scatterplot(x=data['Duration'],y=data['Calories'], hue=data['Pulse'], s=70)
# Out:
# <Axes: xlabel='Duration', ylabel='Calories'>

# %% [markdown]
# ## Heat Maps

# %% [markdown]
# Heatmaps are used to see changes in behavior or gradual changes in data. It uses different colors to represent different values. Based on how these colors range in hues, intensity, etc., tells us how the phenomenon varies.

# %%
sns.heatmap(data, cmap= 'Greens')
# Out:
# <Axes: >

# %% [markdown]
# ## Pie Charts

# %% [markdown]
# A pie chart is a type of graph that represents the data in the circular graph. The slices of pie show the relative size of the data, and it is a type of pictorial representation of data. A pie chart requires a list of categorical variables and numerical variables.

# %%
import matplotlib.pyplot as plt
import numpy as np

y = np.array([35, 25, 25, 15])
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]
mycolors = ["g", "c", "b", "m"]

plt.pie(y, labels = mylabels, colors = mycolors)
plt.legend()
plt.legend(title = "Four Fruits:")
plt.show()

# %%
plt.pie(data['Duration'])
plt.show()
